# %%
import pandas as pd
import numpy as np
exam_data = {'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],
'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']
df = pd.DataFrame(exam_data,columns=['name','score','attempts','qualify'],index=['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j'])
print(df)


df.head(3)
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# d      James    NaN         3      no
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# h      Laura    NaN         1      no
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes

# %%
df=df.dropna (  )

# %%
df[['name', 'score']]
# Out:
#         name  score
# a  Anastasia   12.5
# b       Dima    9.0
# c  Katherine   16.5
# e      Emily    9.0
# f    Michael   20.0
# g    Matthew   14.5
# i      Kevin    8.0
# j      Jonas   19.0

# %%
#Write a Pandas program to append a new row 'k' 
#to data frame with these values(name : "Suresh", score: 15.5, attempts: 1, qualify: "yes")

#dic2={'name':'Suresh','score':15.5,'attempts':1,'qualify':'yes'}
#df=df.append(dic2,ignore_index = False)
#print(df)
df.loc['k']=['suresh',15.5,1,'yes']
df
# Out:
#         name  score  attempts qualify
# a  Anastasia   12.5         1     yes
# b       Dima    9.0         3      no
# c  Katherine   16.5         2     yes
# e      Emily    9.0         2      no
# f    Michael   20.0         3     yes
# g    Matthew   14.5         1     yes
# i      Kevin    8.0         2      no
# j      Jonas   19.0         1     yes
# k     suresh   15.5         1     yes

# %%
df=df.drop(['attempts'], axis=1)
df
# Out:
#         name  score qualify
# a  Anastasia   12.5     yes
# b       Dima    9.0      no
# c  Katherine   16.5     yes
# e      Emily    9.0      no
# f    Michael   20.0     yes
# g    Matthew   14.5     yes
# i      Kevin    8.0      no
# j      Jonas   19.0     yes
# k     suresh   15.5     yes

# %%
# create a list of our conditions
conditions = [
    (df['score'] >10),
    (df['score'] <=10) 
    ]


# create a list of the values we want to assign for each condition
values = [1,0]

# create a new column and use np.select to assign values to it using our lists as arguments
df['success'] = np.select(conditions, values)

# display updated DataFrame
df
# Out:
#         name  score qualify  success
# a  Anastasia   12.5     yes        1
# b       Dima    9.0      no        0
# c  Katherine   16.5     yes        1
# e      Emily    9.0      no        0
# f    Michael   20.0     yes        1
# g    Matthew   14.5     yes        1
# i      Kevin    8.0      no        0
# j      Jonas   19.0     yes        1
# k     suresh   15.5     yes        1

# %%
# C  S V
df.to_csv('df.csv')
new_data=pd.read_csv('df.csv',index_col=[0])
new_data
# Out:
#         name  score qualify  success
# a  Anastasia   12.5     yes        1
# b       Dima    9.0      no        0
# c  Katherine   16.5     yes        1
# e      Emily    9.0      no        0
# f    Michael   20.0     yes        1
# g    Matthew   14.5     yes        1
# i      Kevin    8.0      no        0
# j      Jonas   19.0     yes        1
# k     suresh   15.5     yes        1
